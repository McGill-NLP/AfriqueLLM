# %% [markdown]
# # FineMath Recipe
#
# Use the CLI script for full runs. This notebook is only a short interactive reference.

# %%
from datasets import load_dataset

dataset = load_dataset(
    "HuggingFaceTB/finemath",
    "finemath-4plus",
    split="train",
    streaming=True,
)
next(iter(dataset))

# %%
# Full export command:
# python data/code-math/source_recipes.py finemath \
#   --output data/mixture/finemath-5b \
#   --max_tokens 5000000000
